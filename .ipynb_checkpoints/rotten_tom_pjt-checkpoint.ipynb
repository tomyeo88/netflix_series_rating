# %% [markdown]
# # Rotten Tomatoes PJT

# %% [markdown]
# ## In this project, I will be analyzing the "certified fresh" movies on Netflix (March 2023) by Rotten Tomatoes.
#
# # 1. Introduction
# ## 1.1 Background
# Rotten Tomatoes is a well-known movie rating website where you can find reviews of movie & TV shows by audience or critics.
# The rating metric (aka tomatometer) has 3 groups: the first is "certified fresh" with the best reviews, the second is "fresh" with at least 60% of positive reviews, and the third, "rotten" with less thant 60% of postiive reviews.
#
# Nowadays, OTT service is leading the media industry and Netflix is undoubtably the primary choice for many people around the world. As a result, I wanted to focus on the "certified fresh" movies from Netflix to gain some insights about the popular contents as of now. (2023 March). This project will explore the review data from rotten tomatoes' "Best Movies at Home" list for Netflix series to analyze netflix series with positive reviews.
#
# ## 1.2 Objectives
# In this project, I would like to focus on the followings:
#
# - Learn how to scrape the website using Selenium
# - Analyze content review data to gain some insights:
#     - How is the release date distributed for "certified fresh" rated Netflix movies?
#     - How do critics and audience differ in giving out scores?
#     - What's the most popular titles? (by audience, and by critics)
#     - What's the relationship between sentiment and score?
#
# ## 1.3 Project process
# 1. Web scrape the data from Rotten Tomatoes website using Selenium package
# 2. Save the scraped data in pandas dataframe, and clean the data
# 3. Perform exploratory data analysis
# 4. Conclusions
#
# ## 1.4 Dataset
# ### Data Source
# For this project, I obtained the data myself by web scraping the "certified fresh" movies on Netflix from the Rotten Tomatoes website.
#
# ### Data limitation
# The dataset is a real-world dataset obtained from the movie rating website Rotten Tomatoes. However, since I only scraped the list of best movies at Home on Netflix, it is impossible to compare the "certified fresh" movies with low rated movies to gain further insights. Also, the web scraping is done on the popular list page, which doesn't contain any information about the movie. It might be interesting to actually get the genre, and content category information to enrich analysis which can be the next step for this project.
#
# ### Ethics of data source
# According to the [robots.txt](https://www.rottentomatoes.com/robots.txt) file of Rotten Tomatoes, web scraping is allowed by the company unless the user use "/search" or "/user/id" url path. I sticked to web scraping only Best Movies at Home on Netflix (March 2023) page, so I did not violate the robots.txt rule.
# Also, the data is used for research purposes only.

# %%
# Import basic libraries (dataframe, visualization purpose)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Web scraping libraries
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# Install webdriver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.84M/8.84M [00:00<00:00, 13.0MB/s]
# /var/folders/vk/y7f8_5d11n9gb0mnty5f0h9h0000gn/T/ipykernel_60762/1314421596.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# # 2. Scrape the web page with Selenium Package

# %% [markdown]
# First, I installed a Chrome webdriver, and got the page_url to do the web scraping. Using Selenium, I was able to load all the movie list from the web page. Afterwards, I got all the data into list variables and created a pandas dataframe with multiple columns containing all the data.

# %% [markdown]
# ### Get elements from the page url

# %%
# Get Rotten Tomatoes netflix recommendation list page url
page_url = "https://www.rottentomatoes.com/browse/movies_at_home/affiliates:netflix~critics:certified_fresh"
driver.implicitly_wait(5)
driver.get(page_url)

# %% [markdown]
# ### Scroll the page to load all the data

# %%
from selenium.common.exceptions import ElementNotInteractableException

# Get the total scroll size
last_height = driver.execute_script('return document.documentElement.scrollHeight')

# Scroll until the scroll size doesn't change
while True:
    # Scroll to the end
    driver.execute_script('window.scrollTo(0, document.documentElement.scrollHeight)')
    time.sleep(3)
    
    # Click the load more button
    try:
        button = driver.find_element(By.XPATH, '//button[text()="Load more"]')
        button.click()
        time.sleep(3)
        
        # Get the current height
        now_height = driver.execute_script('return document.documentElement.scrollHeight')
        
    except ElementNotInteractableException:
        # If I can't load more items, break the loop
        break

        
time.sleep(1.5)

# %% [markdown]
# ### Get all the data from the loaded page

# %%
# Get title, and start_date
title = driver.find_elements(By.XPATH, ".//span[@data-qa='discovery-media-list-item-title']")
start_date = driver.find_elements(By.XPATH, ".//span[@data-qa='discovery-media-list-item-start-date']")

title_list = []

for t in title:
    title_list.append(t.text)

start_date_list = []

for sd in start_date:
    start_date_list.append(sd.text)

# Get review score and sentiment
score_pairs = driver.find_elements(By.XPATH, ".//score-pairs")
aud_sentiment = []
aud_score = []
crit_sentiment = []
crit_score = []

for pair in score_pairs:
    aud_sentiment.append(pair.get_attribute("audiencesentiment"))
    aud_score.append(pair.get_attribute("audiencescore"))
    crit_sentiment.append(pair.get_attribute("criticssentiment"))
    crit_score.append(pair.get_attribute("criticsscore"))

# %% [markdown]
# ### Put all the data into a pandas dataframe

# %%
# Put data into a pandas dataframe
rotten_df = pd.DataFrame({'title':title_list, 'start_date':start_date_list, 'aud_sentiment':aud_sentiment,
              'aud_score':aud_score, 'crit_sentiment':crit_sentiment,
              'crit_score':crit_score})

# %% [markdown]
# ### Get Data Info

# %% [markdown]
# Using `head` function to check if the data is put in the dataframe correctly.

# %%
rotten_df.head()
# Out:
#                                title              start_date aud_sentiment  \
# 0                     The Woman King  Streaming Dec 13, 2022      positive
# 1                 Emily the Criminal  Streaming Oct 28, 2022      positive
# 2                     Leave No Trace  Streaming Sep 25, 2018      positive
# 3                       The Stranger  Streaming Oct 19, 2022      positive
# 4  Glass Onion: A Knives Out Mystery  Streaming Dec 23, 2022      positive
#
#   aud_score crit_sentiment crit_score
# 0        99       positive         94
# 1        79       positive         94
# 2        80       positive        100
# 3        67       positive         91
# 4        92       positive         92

# %% [markdown]
# Now check the data types of each column, using `info` function.

# %%
rotten_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           258 non-null    object
#  1   start_date      258 non-null    object
#  2   aud_sentiment   258 non-null    object
#  3   aud_score       258 non-null    object
#  4   crit_sentiment  258 non-null    object
#  5   crit_score      258 non-null    object
# dtypes: object(6)
# memory usage: 12.2+ KB

# %%
# Print data info
print('Total number of data:', rotten_df.shape[0]*rotten_df.shape[1])
print('Total number of null values: {} = {:.2f}% of data'.format(rotten_df.isnull().sum().sum(),
     (rotten_df.isnull().sum().sum()/rotten_df.shape[0]*rotten_df.shape[1])))
# Out:
# Total number of data: 1548
# Total number of null values: 0 = 0.00% of data

# %% [markdown]
# I found that there are no null values, but all the data types are in object dtype, so I have to change the data types of each column to match the characteristics of each column, and also watch out for any non-null values with empty string `''`.

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# Since it's web scraped data, there could be null values as empty string `''`. I excluded the data with empty strings first and saved the dataset as a csv file, because I do not want to web scrape the data everytime I have to revert back to the original dataframe.
# Afterwards, I changed the data type of columns to appropriate types.

# %% [markdown]
# ### Find '' values and exclude them from the data

# %%
rotten_df.query('aud_score == ""')
# Out:
#                                                  title  \
# 174                      Disappearance at Clifton Hill
# 237  Rolling Thunder Revue: A Bob Dylan Story by Ma...
#
#                  start_date aud_sentiment aud_score crit_sentiment crit_score
# 174  Streaming Feb 28, 2020                               positive         76
# 237  Streaming Jun 12, 2019                               positive         92

# %%
rotten_df = rotten_df.query('aud_score != ""').copy()

# %% [markdown]
# ### Dataframe from the csv file (created)

# %%
# Copy the dataframe to csv so I can use it later on without scraping again.
rotten_df.to_csv('rotten_df.csv', index=False)

# %%
# Read csv file back
rotten_df = pd.read_csv('rotten_df.csv')

# %% [markdown]
# ### Change data type of columns

# %% [markdown]
# I noticed the 'start_date' column has "Streaming" text value in each row, which needs to be deleted. <br>
# Date columns should be converted to datetime object, and core values to numeric values (float type)

# %%
# Need to get rid of "Streaming" text
rotten_df['start_date']
# Out:
# 0      Streaming Dec 13, 2022
# 1      Streaming Oct 28, 2022
# 2      Streaming Sep 25, 2018
# 3      Streaming Oct 19, 2022
# 4      Streaming Dec 23, 2022
#                 ...
# 251    Streaming Apr 28, 2017
# 252     Streaming Nov 7, 2017
# 253    Streaming Aug 26, 2020
# 254     Streaming Dec 4, 2018
# 255    Streaming Jan 19, 2017
# Name: start_date, Length: 256, dtype: object

# %%
# Change start_date column to datetime
rotten_df['start_date'] = rotten_df['start_date'].apply(lambda x: x.split('Streaming')[1])
rotten_df['start_date'] = pd.to_datetime(rotten_df['start_date'])

# Change aud_score, crit_score to int
rotten_df[['aud_score','crit_score']] = rotten_df[['aud_score','crit_score']].astype(int)

# %%
rotten_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           256 non-null    object
#  1   start_date      256 non-null    datetime64[ns]
#  2   aud_sentiment   256 non-null    object
#  3   aud_score       256 non-null    int64
#  4   crit_sentiment  256 non-null    object
#  5   crit_score      256 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 12.1+ KB

# %% [markdown]
# We find that date types are changed accordingly. However, additional datetime columns such as year_month, month, year can be helpful in analysis so I will add these 3 columns.

# %% [markdown]
# ### Add year_month, year, month column

# %%
# add year-month column from the start_date
rotten_df['year_month'] = rotten_df['start_date'].dt.strftime('%Y-%m')
rotten_df['month'] = rotten_df['start_date'].dt.month
rotten_df['year'] = rotten_df['start_date'].dt.year

# %% [markdown]
# # 4. Perform EDA

# %% [markdown]
# ### Number of certified fresh-rated Netflix movies by year-month

# %% [markdown]
# By observing the number of certified fresh-rated Netflix movies by year-month, year, and month respectively, we can see how the release date of fresh rated Netflix movies are distributed.
# The number of positively rated Netflix titles increased over the years until 2017, but began to decline afterwards, with 2017 May as the peak period.
# The fresh rated movies tend to be released more on April, October, and November as well. We don't know exactly why from this dataset, but it certainly seems like positively rated Netflix movies decreased recently compared to 5-6 years ago. However, we need Netflix titles with lower rated data as well to determine if the proportion of fresh rated titles actually declined or the total number of Netflix titles reviewed by Rotten Tomatoes declined in recent years.

# %%
# When did many good movies from Netflix came out?
ym_cnt = rotten_df['year_month'].value_counts().reset_index()\
         .rename(columns={'index':'year_month','year_month':'count'})

# Barchart with Top 10 dates with the most "fresh" Netflix movies
f, ax = plt.subplots(1,1, figsize=(10,5))
sns.barplot(y='year_month', x='count', palette= 'coolwarm', data=ym_cnt.head(10))
ax.set_xlabel('# of movies released', fontsize=10)
ax.set_ylabel('Year-Month', fontsize=10)
ax.set_title('Top 10 Dates with good Netflix movies')
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize=(15,6))

# Count the number of titles by year
year_cnt = rotten_df.groupby('year')['title'].count().reset_index()

# Most popular year of release date among "fresh" Netflix movies (barplot)
sns.barplot(x='year', y='title', data=year_cnt, palette='magma', ax=ax[0])
ax[0].set_title('Number of movies released by year', fontsize=15)
ax[0].set_ylabel('Count', fontsize=12)
ax[0].set_xlabel('Year', fontsize=12)

# Calculate the bin edges and widths for histplot
bins = np.linspace(rotten_df['month'].min(), rotten_df['month'].max(), num=13)
width = bins[1] - bins[0]

# Most popular month of release date among "fresh" Netflix movies (histplot)
sns.histplot(rotten_df['month'], bins=bins, color='firebrick', kde=True, ax=ax[1])
ax[1].set_title('Number of movies released by month', fontsize=15)
ax[1].set_ylabel('', fontsize=12)
ax[1].set_xlabel('Month', fontsize=12)

# set the x-axis tick locations to be the center of each bin with month text value as a label
ax[1].set_xticks(bins[:-1] + width/2)
ax[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

plt.show()

# %% [markdown]
# ### How do audience and critics differ in giving out scores?

# %% [markdown]
# Movie rating is a subjective measurement and since Rotten Tomatoes give separate scores for audience and critics, I wanted to know if there's a difference between the two groups in giving out scores.
# First, I plotted a boxplot to easily compare the distribution of scores for each group. We can see that audience score is widely spread out from the median, whereas critics score is mostly centered around the median. Next, I grouped the score data for audience and critics respectively into 3 groups (popular, neutral, unpopular) based on their score distribution. <br> To compare the scoring patterns between the two, I plotted two scattergrams with 3 groups as hue option to clearly see the difference between audience scores and critics'. We can observe that if the title was popular among the audience, critics usually loved the title as well. However, vice versa was not the case, because some of the most popular titles among critics actually got really low scores from the audience. It is hard to pinpoint why critics tend to give higher scores, but one reason could be that they care more about the movie distributors or production companies's interests since it might affect their business opportunities in the future. Also, they can put more value into the title's artistic value or social values whereas audience might put more empasis on entertainment value.

# %%
# Compare the distribution of scores between audience and critics
aud_cnt = rotten_df.groupby('aud_score')['title'].count().reset_index()
crit_cnt = rotten_df.groupby('crit_score')['title'].count().reset_index()

# Plot boxplot to see the different score distribution between audience and critics
f, ax = plt.subplots(1,2, figsize=(10,6))
sns.boxplot(aud_cnt['aud_score'], ax=ax[0], color='darkgreen', medianprops=dict(color='white'))
ax[0].set_ylim(0,120)
sns.boxplot(crit_cnt['crit_score'], ax=ax[1], color='indigo', medianprops=dict(color='white'))
ax[1].set_ylim(0,120)
# Out:
# (0.0, 120.0)

# %% [markdown]
# I also printed out the acutal values in the boxplot to compare the two groups (audience, critics)

# %%
# Median, 1st quartile, 3rd quartile value of audience and critics score
audience_median = aud_cnt['aud_score'].median()
critics_median = crit_cnt['crit_score'].median()
audience_1q = aud_cnt['aud_score'].quantile(0.25)
critics_1q = crit_cnt['crit_score'].quantile(0.25)
audience_3q = aud_cnt['aud_score'].quantile(0.75)
critics_3q = crit_cnt['crit_score'].quantile(0.75)
audience_std = aud_cnt['aud_score'].std()
critics_std = crit_cnt['crit_score'].std()

print(f"The median value of audience score is {audience_median}, and the median value of critics score is {critics_median}")
print(f"The 1q value of audience score is {audience_1q}, and the 1q value of critics score is {critics_1q}")
print(f"The 3q value of audience score is {audience_3q}, and the 3q value of critics score is {critics_3q}")
print(f"The standard deviation of audience score is {audience_std}, and the standard deviation of critics score is {critics_std}")
# Out:
# The median value of audience score is 70.0, and the median value of critics score is 86.0
# The 1q value of audience score is 55.0, and the 1q value of critics score is 79.0
# The 3q value of audience score is 85.0, and the 3q value of critics score is 93.0
# The standard deviation of audience score is 19.753453042539807, and the standard deviation of critics score is 8.575224939243325

# %% [markdown]
# Now, I divided the scores into 3 groups using `pd.cut` function:
# - popular: 80% or highger
# - neutral: 50% to 80%
# - unpopular: below 50%

# %%
# Get the 50, 80% score from audience, and critics score
print(np.percentile(aud_cnt['aud_score'], 50))
print(np.percentile(crit_cnt['crit_score'], 50))
print(np.percentile(aud_cnt['aud_score'], 80))
print(np.percentile(crit_cnt['crit_score'], 80))
# Out:
# 70.0
# 86.0
# 88.0
# 94.4

# %%
# Divide the data into popular, neutral, unpopular groups
aud_bins = pd.cut(rotten_df['aud_score'], bins=[0,70,88,100], labels=['unpopular','neutral','popular'])
rotten_df['aud_popularity'] = aud_bins

crit_bins = pd.cut(rotten_df['crit_score'], bins=[0,86,94.4,100], labels=['unpopular','neutral','popular'])
rotten_df['crit_popularity'] = crit_bins

# %% [markdown]
# Then, I plotted two scattergrams with audience, critics popularity group as `hue` parameter.

# %%
# Scatterplot between audience score and critics score with popularity hues

# First scatterplot with audience popularity
f, ax = plt.subplots(1,2, figsize=(20,8))
ax[0].set_title('Audience score vs Critics score (Audience popularity)', fontsize=15)
sns.scatterplot(x='aud_score', y='crit_score', data=rotten_df, hue='aud_popularity', ax=ax[0])
ax[0].set_ylim(0,110)
ax[0].legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0., title='Audience', frameon=True, prop={'size': 10},
           title_fontsize=10, markerscale=0.6, labelspacing=0.6, handletextpad=0.5, handlelength=0.8)

# Second scatterplot with critics popularity
ax[1].set_title('Ciritcs score vs Audience score (Critics popularity)', fontsize=15)
sns.scatterplot(x='crit_score', y='aud_score', data=rotten_df, hue='crit_popularity', ax=ax[1])
ax[1].set_xlim(0,110)
ax[1].legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0., title='Critics', frameon=True, prop={'size': 10},
           title_fontsize=10, markerscale=0.6, labelspacing=0.6, handletextpad=0.5, handlelength=0.8)
plt.show()

# %% [markdown]
# ### What are some of the most popular titles by audience and critics?

# %% [markdown]
# I wanted to separate the data into two. One with titles popular among audience but not among critics, and vice versa. Before I plotted the scattergram with title names, I noticed that some titles had same audience score and critics score combinations. So, I positioned the labels with `adjustText` library's `adjust_text` function to print out the labels properly. <br>
#
# We can see that some titles were relatively more popular among the audience.
# - "Official Secrets": audience score: 89, critics score: 82
# - "Lion": audience score: 91, critics score: 84
#
# Some titles were only popular among critics and poorly rated by audience.
# - "Knock Down the House": critics score: 99, audience score: 11
# - "Hannah Gadsby: Nanette": critics score: 100 , audience score: 22
# - "Is That Black Enough for You?!?": critics score: 100, audience score: 66
#
# We cannot determine for sure why such score discrepancy occurs in these titles. Maybe gathering more information about these titles can help finding the reasons.

# %%
aud_preferred = rotten_df.query('aud_popularity=="popular" and crit_popularity!="popular"')[['title','aud_score','crit_score']].reset_index(drop=True)
crit_preferred = rotten_df.query('crit_popularity=="popular" and aud_popularity!="popular"')[['title','aud_score','crit_score']].reset_index(drop=True)

# %% [markdown]
# I noticed the duplicated values in `aud_score`, `crit_score` combination.

# %%
# Need to adjust scatterplot labels due to duplicated values below
aud_preferred[aud_preferred.duplicated(['aud_score','crit_score'], keep=False)].sort_values(by='aud_score')
# Out:
#                                        title  aud_score  crit_score
# 11           National Lampoon's Animal House         89          91
# 16                                 Philomena         89          91
# 22  Rumble: The Indians Who Rocked the World         89          91
# 9                         The Imitation Game         91          90
# 21                  Adam Sandler: 100% Fresh         91          90
# 5                       The Harder They Fall         93          88
# 6                               The Bad Guys         93          88

# %% [markdown]
# I used adjustText package to adjust the label positions properly and plot the data in two separate scattergrams.

# %%
from adjustText import adjust_text

f, ax = plt.subplots(1,2, figsize=(20,10))

# Plot 1st scatterplot (popular among audience)
sns.scatterplot(x='aud_score', y='crit_score', data=aud_preferred, alpha=0.7, ax=ax[0])

# Add labels to the scatterplot
texts1 = []
for i, label in enumerate(aud_preferred['title']):
    texts1.append(ax[0].text(aud_preferred.loc[i, 'aud_score'], aud_preferred.loc[i, 'crit_score'], label))

# Adjust label positions 
adjust_text(texts1, ax=ax[0])

# Set x, ylabel
ax[0].set_xlabel('Audience Score')
ax[0].set_ylabel('Critics Score')

# Set title
ax[0].set_title('Popular titles only among audience', fontsize=15, pad=10)

# Plot 2nd scatterplot (popular amdong critics)
sns.scatterplot(x='aud_score', y='crit_score', data=crit_preferred, alpha=0.7, ax=ax[1])

# Add labels to the scatterplot
texts2 = []
for i, label in enumerate(crit_preferred['title']):
    texts2.append(ax[1].text(crit_preferred.loc[i, 'aud_score'], crit_preferred.loc[i, 'crit_score'], label))

# Adjust label positions 
adjust_text(texts2, ax=ax[1])

# Set x, ylabel
ax[1].set_xlabel('Audience Score')
ax[1].set_ylabel('')

# Set title
ax[1].set_title('Popular titles only among critics', fontsize=15, pad=10)

plt.show()

# %% [markdown]
# ### What's the relationship between sentiment and score?

# %% [markdown]
# Rotten Tomatoes' reviews also had sentiment values, so I wanted to find out the relationship between sentiment and score. I plotted violinplot for positive, and negative sentiment with audience score and critics score as values. As you can see from the violinplot, the audience score of titles with positive sentiment approximately has 20+ score points than the titles with negative sentiment, and audience score of positive sentiment is more spread out.
#
# On the other hand, critics did not have even one title with negative sentiment, which is surprising since 16% of the certified fresh rated Netflix titles were "negative" among audience. The absence of any titles with negative sentiment raises doubts about whether critics are completely honest in expressing their negative opinions."

# %%
# Create a violinplot of the relationship bewteen sentiment and score
f, ax = plt.subplots(1,2, figsize=(10,6))

# Audience violinplot
sns.violinplot(x='aud_sentiment', y='aud_score', data = rotten_df, ax=ax[0])
ax[0].set_ylim(bottom=0, top=120)
ax[0].set_xlabel('Audience Sentiment', fontsize=12)
ax[0].set_ylabel('Audience Score', fontsize=12)

# Critics violinplot
sns.violinplot(x='crit_sentiment', y='crit_score', data = rotten_df, ax=ax[1])
ax[1].set_ylim(bottom=0, top=120)
ax[1].set_xlabel('Critics Sentiment', fontsize=12)
ax[1].set_ylabel('Critics Score', fontsize=12)
     
plt.suptitle('The relationship between sentiment and score', fontsize=15)
plt.show()

# %% [markdown]
# # 5. Conclusions

# %% [markdown]
# In this project, we have explored the Rotten Tomatoes' Best Movies at Home on Netflix (March 2023) webpage's title review data by scraping the title information, and demonstrated some interesting findings about the review data:
#
# - The number of certified fresh rated Netflix movies in rotten tomatoes increased over time till 2017, and then gradually decreased.
# - The most popular release date (month) for certified fresh rated movies were April, October, and November.
# - Audience score was more spread out than critics score, and audience had negative sentiment about 16% of the certified fresh rated Netflix movies.
# - Critics tend to give higher scores than audience, and did not have a single title with negative sentiment.
# - Some of the titles that are highly praised by critics had very low score from the audience.

# %% [markdown]
# #### Project limitations

# %% [markdown]
# The findings illustrate some interesting points, but have limiations for a number of reasons:
# - There were only 256 Netflix titles rated as certified fresh by Rotten Tomatoes, so it's hard to find the overall trend from small dataset.
# - I do not know exactly how certified fresh rating is given, and may not represent all the best Netflix movies.
# - I only have the title name, review scores, and sentiment information. I would need more information about the titles to come up with a reasonable hypothesis of why the critics' and audience scores differ by such a large amount.

# %% [markdown]
# #### Ideas for future research

# %% [markdown]
# To further the research, one can:
# - Expand the dataset to include fresh rated, and rotten rated Netflix titles.
# - Expand the dataset to include other OTT contents and compare the review trends among these OTT platforms.
# - Get more data about each title, including genre, categories, actors, and producers to find out why certain titles are favored by audience or critics.
# - Scrape actual review comments to have more context on the ratings.
